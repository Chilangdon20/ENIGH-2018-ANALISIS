# %% [markdown]
# Objetivos:
#
# 1. Identificar cada una de las variables si es:
#      * cualitativa
#      * cuantitativa discreta
#      *  cuantitativa continua.
# 2. Histograma qué distribución sigue?

# %%
import pandas as pd

data = pd.read_csv('/content/conjunto_de_datos_concentradohogar_enigh_2018_ns.csv')

data.sample(n=25)
# Out:
#          folioviv  foliohog  ubica_geo  ...  balance  otras_erog     smg
# 69263  3061905713         1      30094  ...      0.0        0.00  7952.4
# 61389  2606209701         1      26018  ...      0.0        0.00  7952.4
# 8667    400793405         1       4003  ...      0.0        0.00  7952.4
# 38251  1604712315         1      16025  ...      0.0    10594.55  7952.4
# 3512    206990013         1       2002  ...      0.0        0.00  7952.4
# 24097  1001660904         1      10007  ...      0.0        0.00  7952.4
# 16428   703743315         1       7031  ...      0.0        0.00  7952.4
# 73646  3202439318         1      32050  ...      0.0        0.00  7952.4
# 23675  1000546804         1      10005  ...      0.0        0.00  7952.4
# 40232  1702851701         1      17011  ...      0.0        0.00  7952.4
# 47861  2061768309         1      20439  ...      0.0        0.00  7952.4
# 3456    206787201         1       2004  ...      0.0        0.00  7952.4
# 66267  2900545002         1      29025  ...      0.0        0.00  7952.4
# 64893  2806047403         1      28038  ...      0.0        0.00  7952.4
# 58538  2503648505         1      25012  ...      0.0        0.00  7952.4
# 37685  1602091305         1      16102  ...      0.0        0.00  7952.4
# 3780    208036902         1       2004  ...      0.0        0.00  7952.4
# 42673  1860203226         1      18001  ...      0.0        0.00  7952.4
# 21630   903628704         1       9005  ...      0.0        0.00  7952.4
# 55460  2401931405         1      24028  ...      0.0        0.00  7952.4
# 1002    101730205         1       1001  ...      0.0        0.00  7952.4
# 43209  1901367905         1      19019  ...      0.0        0.00  7952.4
# 46366  2001400803         1      20079  ...      0.0        0.00  7952.4
# 73857  3260029617         1      32010  ...      0.0        0.00  7952.4
# 62060  2660714409         1      26032  ...      0.0        0.00  7952.4
#
# [25 rows x 126 columns]

# %%
#procedemos a ver los nobres de las columas

data.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74647 entries, 0 to 74646
# Data columns (total 126 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   folioviv    int64
#  1   foliohog    int64
#  2   ubica_geo   int64
#  3   tam_loc     int64
#  4   est_socio   int64
#  5   est_dis     int64
#  6   upm         int64
#  7   factor      int64
#  8   clase_hog   int64
#  9   sexo_jefe   int64
#  10  edad_jefe   int64
#  11  educa_jefe  int64
#  12  tot_integ   int64
#  13  hombres     int64
#  14  mujeres     int64
#  15  mayores     int64
#  16  menores     int64
#  17  p12_64      int64
#  18  p65mas      int64
#  19  ocupados    int64
#  20  percep_ing  int64
#  21  perc_ocupa  int64
#  22  ing_cor     float64
#  23  ingtrab     float64
#  24  trabajo     float64
#  25  sueldos     float64
#  26  horas_extr  float64
#  27  comisiones  float64
#  28  aguinaldo   float64
#  29  indemtrab   float64
#  30  otra_rem    float64
#  31  remu_espec  float64
#  32  negocio     float64
#  33  noagrop     float64
#  34  industria   float64
#  35  comercio    float64
#  36  servicios   float64
#  37  agrope      float64
#  38  agricolas   float64
#  39  pecuarios   float64
#  40  reproducc   float64
#  41  pesca       float64
#  42  otros_trab  float64
#  43  rentas      float64
#  44  utilidad    float64
#  45  arrenda     float64
#  46  transfer    float64
#  47  jubilacion  float64
#  48  becas       float64
#  49  donativos   float64
#  50  remesas     float64
#  51  bene_gob    float64
#  52  transf_hog  float64
#  53  trans_inst  float64
#  54  estim_alqu  float64
#  55  otros_ing   float64
#  56  gasto_mon   float64
#  57  alimentos   float64
#  58  ali_dentro  float64
#  59  cereales    float64
#  60  carnes      float64
#  61  pescado     float64
#  62  leche       float64
#  63  huevo       float64
#  64  aceites     float64
#  65  tuberculo   float64
#  66  verduras    float64
#  67  frutas      float64
#  68  azucar      float64
#  69  cafe        float64
#  70  especias    float64
#  71  otros_alim  float64
#  72  bebidas     float64
#  73  ali_fuera   float64
#  74  tabaco      float64
#  75  vesti_calz  float64
#  76  vestido     float64
#  77  calzado     float64
#  78  vivienda    float64
#  79  alquiler    float64
#  80  pred_cons   float64
#  81  agua        float64
#  82  energia     float64
#  83  limpieza    float64
#  84  cuidados    float64
#  85  utensilios  float64
#  86  enseres     float64
#  87  salud       float64
#  88  atenc_ambu  float64
#  89  hospital    float64
#  90  medicinas   float64
#  91  transporte  float64
#  92  publico     float64
#  93  foraneo     float64
#  94  adqui_vehi  float64
#  95  mantenim    float64
#  96  refaccion   float64
#  97  combus      float64
#  98  comunica    float64
#  99  educa_espa  float64
#  100 educacion   float64
#  101 esparci     float64
#  102 paq_turist  float64
#  103 personales  float64
#  104 cuida_pers  float64
#  105 acces_pers  float64
#  106 otros_gas   float64
#  107 transf_gas  float64
#  108 percep_tot  float64
#  109 retiro_inv  float64
#  110 prestamos   float64
#  111 otras_perc  float64
#  112 ero_nm_viv  float64
#  113 ero_nm_hog  float64
#  114 erogac_tot  float64
#  115 cuota_viv   float64
#  116 mater_serv  float64
#  117 material    float64
#  118 servicio    float64
#  119 deposito    float64
#  120 prest_terc  float64
#  121 pago_tarje  float64
#  122 deudas      float64
#  123 balance     float64
#  124 otras_erog  float64
#  125 smg         float64
# dtypes: float64(104), int64(22)
# memory usage: 71.8 MB

# %%
# seleccionamos las columnas que son de tipo cualitativo y cuantiativo
variables_cuali = data.iloc[:,0:12]
variables_cuanti = data.iloc[:,13:]
var_cuanti = variables_cuanti.columns

# %%
# Añdimos las columnas cuantitativas que hacen falta
variables_cuanti_2 = data[['est_dis','upm','factor']]
var_cuantitativa = pd.concat([variables_cuanti,variables_cuanti_2],axis='columns')

# %%
# eliminamos algunas columnas cuantiativas dentro de las cualitativas
variables_cuali.drop(['est_dis','upm','factor'], axis='columns',inplace=True)
var_cuali = variables_cuali.columns

# %% [markdown]
# Procedemos a identificar que variables son cualitativas y que variables son cuantitativas, maas adelante identificaremos las discretas y las continuas.

# %%
# imprimimos las columnas cualitativas
for i in var_cuali:

  print("La columna {} es: cualitativa ".format(i))
# Out:
# La columna folioviv es: cualitativa
# La columna foliohog es: cualitativa
# La columna ubica_geo es: cualitativa
# La columna tam_loc es: cualitativa
# La columna est_socio es: cualitativa
# La columna clase_hog es: cualitativa
# La columna sexo_jefe es: cualitativa
# La columna edad_jefe es: cualitativa
# La columna educa_jefe es: cualitativa

# %%
for i in var_cuantitativa:
  print("La columna {} es: cuantitativa".format(i))
# Out:
# La columna hombres es: cuantitativa
# La columna mujeres es: cuantitativa
# La columna mayores es: cuantitativa
# La columna menores es: cuantitativa
# La columna p12_64 es: cuantitativa
# La columna p65mas es: cuantitativa
# La columna ocupados es: cuantitativa
# La columna percep_ing es: cuantitativa
# La columna perc_ocupa es: cuantitativa
# La columna ing_cor es: cuantitativa
# La columna ingtrab es: cuantitativa
# La columna trabajo es: cuantitativa
# La columna sueldos es: cuantitativa
# La columna horas_extr es: cuantitativa
# La columna comisiones es: cuantitativa
# La columna aguinaldo es: cuantitativa
# La columna indemtrab es: cuantitativa
# La columna otra_rem es: cuantitativa
# La columna remu_espec es: cuantitativa
# La columna negocio es: cuantitativa
# La columna noagrop es: cuantitativa
# La columna industria es: cuantitativa
# La columna comercio es: cuantitativa
# La columna servicios es: cuantitativa
# La columna agrope es: cuantitativa
# La columna agricolas es: cuantitativa
# La columna pecuarios es: cuantitativa
# La columna reproducc es: cuantitativa
# La columna pesca es: cuantitativa
# La columna otros_trab es: cuantitativa
# La columna rentas es: cuantitativa
# La columna utilidad es: cuantitativa
# La columna arrenda es: cuantitativa
# La columna transfer es: cuantitativa
# La columna jubilacion es: cuantitativa
# La columna becas es: cuantitativa
# La columna donativos es: cuantitativa
# La columna remesas es: cuantitativa
# La columna bene_gob es: cuantitativa
# La columna transf_hog es: cuantitativa
# La columna trans_inst es: cuantitativa
# La columna estim_alqu es: cuantitativa
# La columna otros_ing es: cuantitativa
# La columna gasto_mon es: cuantitativa
# La columna alimentos es: cuantitativa
# La columna ali_dentro es: cuantitativa
# La columna cereales es: cuantitativa
# La columna carnes es: cuantitativa
# La columna pescado es: cuantitativa
# La columna leche es: cuantitativa
# La columna huevo es: cuantitativa
# La columna aceites es: cuantitativa
# La columna tuberculo es: cuantitativa
# La columna verduras es: cuantitativa
# La columna frutas es: cuantitativa
# La columna azucar es: cuantitativa
# La columna cafe es: cuantitativa
# La columna especias es: cuantitativa
# La columna otros_alim es: cuantitativa
# La columna bebidas es: cuantitativa
# La columna ali_fuera es: cuantitativa
# La columna tabaco es: cuantitativa
# La columna vesti_calz es: cuantitativa
# La columna vestido es: cuantitativa
# La columna calzado es: cuantitativa
# La columna vivienda es: cuantitativa
# La columna alquiler es: cuantitativa
# La columna pred_cons es: cuantitativa
# La columna agua es: cuantitativa
# La columna energia es: cuantitativa
# La columna limpieza es: cuantitativa
# La columna cuidados es: cuantitativa
# La columna utensilios es: cuantitativa
# La columna enseres es: cuantitativa
# La columna salud es: cuantitativa
# La columna atenc_ambu es: cuantitativa
# La columna hospital es: cuantitativa
# La columna medicinas es: cuantitativa
# La columna transporte es: cuantitativa
# La columna publico es: cuantitativa
# La columna foraneo es: cuantitativa
# La columna adqui_vehi es: cuantitativa
# La columna mantenim es: cuantitativa
# La columna refaccion es: cuantitativa
# La columna combus es: cuantitativa
# La columna comunica es: cuantitativa
# La columna educa_espa es: cuantitativa
# La columna educacion es: cuantitativa
# La columna esparci es: cuantitativa
# La columna paq_turist es: cuantitativa
# La columna personales es: cuantitativa
# La columna cuida_pers es: cuantitativa
# La columna acces_pers es: cuantitativa
# La columna otros_gas es: cuantitativa
# La columna transf_gas es: cuantitativa
# La columna percep_tot es: cuantitativa
# La columna retiro_inv es: cuantitativa
# La columna prestamos es: cuantitativa
# La columna otras_perc es: cuantitativa
# La columna ero_nm_viv es: cuantitativa
# La columna ero_nm_hog es: cuantitativa
# La columna erogac_tot es: cuantitativa
# La columna cuota_viv es: cuantitativa
# La columna mater_serv es: cuantitativa
# La columna material es: cuantitativa
# La columna servicio es: cuantitativa
# La columna deposito es: cuantitativa
# La columna prest_terc es: cuantitativa
# La columna pago_tarje es: cuantitativa
# La columna deudas es: cuantitativa
# La columna balance es: cuantitativa
# La columna otras_erog es: cuantitativa
# La columna smg es: cuantitativa
# La columna est_dis es: cuantitativa
# La columna upm es: cuantitativa
# La columna factor es: cuantitativa

# %% [markdown]
# Procedemos a identificar el tipo de variable cuantitativa:
#
# * discreta - Son aquellas que obedecen a una cantidad numérica exacta, que puede tomar **únicamente valores enteros y que sólo puede tomar valores dentro de un conjunto definido.**
#
# * continua -  Son variables numéricas que permiten **expresiones decimales porque pueden tomar cualquier valor real dentro de un intervalo** (es decir, hay infinitas posibilidades).

# %%
variables_cuanti.head()
# Out:
#    hombres  mujeres  mayores  menores  ...    deudas  balance  otras_erog     smg
# 0        2        1        3        0  ...      0.00      0.0         0.0  7952.4
# 1        2        3        5        0  ...      0.00      0.0         0.0  7952.4
# 2        1        1        2        0  ...  14754.09      0.0         0.0  7952.4
# 3        1        1        2        0  ...      0.00      0.0         0.0  7952.4
# 4        1        3        3        1  ...      0.00      0.0         0.0  7952.4
#
# [5 rows x 113 columns]

# %%
# Separamos las culumnas por discretas y continuas
var_cuanti_discret = ['hombres','mujeres','mayores','menores','p12_64','p65mas','ocupados','percep_ing','perc_ocupa']

for i in var_cuanti_discret:
  print("La columna {} es una vaiable continua discreta".format(i))
# Out:
# La columna hombres es una vaiable continua discreta
# La columna mujeres es una vaiable continua discreta
# La columna mayores es una vaiable continua discreta
# La columna menores es una vaiable continua discreta
# La columna p12_64 es una vaiable continua discreta
# La columna p65mas es una vaiable continua discreta
# La columna ocupados es una vaiable continua discreta
# La columna percep_ing es una vaiable continua discreta
# La columna perc_ocupa es una vaiable continua discreta

# %%
var_cuanti_conti = variables_cuanti.drop(var_cuanti_discret , axis=1)

cuanti_cont_list = var_cuanti_conti.columns
for i in cuanti_cont_list:
  print("La variiable {} es cuantitativa continua.".format(i))
# Out:
# La variiable ing_cor es cuantitativa continua.
# La variiable ingtrab es cuantitativa continua.
# La variiable trabajo es cuantitativa continua.
# La variiable sueldos es cuantitativa continua.
# La variiable horas_extr es cuantitativa continua.
# La variiable comisiones es cuantitativa continua.
# La variiable aguinaldo es cuantitativa continua.
# La variiable indemtrab es cuantitativa continua.
# La variiable otra_rem es cuantitativa continua.
# La variiable remu_espec es cuantitativa continua.
# La variiable negocio es cuantitativa continua.
# La variiable noagrop es cuantitativa continua.
# La variiable industria es cuantitativa continua.
# La variiable comercio es cuantitativa continua.
# La variiable servicios es cuantitativa continua.
# La variiable agrope es cuantitativa continua.
# La variiable agricolas es cuantitativa continua.
# La variiable pecuarios es cuantitativa continua.
# La variiable reproducc es cuantitativa continua.
# La variiable pesca es cuantitativa continua.
# La variiable otros_trab es cuantitativa continua.
# La variiable rentas es cuantitativa continua.
# La variiable utilidad es cuantitativa continua.
# La variiable arrenda es cuantitativa continua.
# La variiable transfer es cuantitativa continua.
# La variiable jubilacion es cuantitativa continua.
# La variiable becas es cuantitativa continua.
# La variiable donativos es cuantitativa continua.
# La variiable remesas es cuantitativa continua.
# La variiable bene_gob es cuantitativa continua.
# La variiable transf_hog es cuantitativa continua.
# La variiable trans_inst es cuantitativa continua.
# La variiable estim_alqu es cuantitativa continua.
# La variiable otros_ing es cuantitativa continua.
# La variiable gasto_mon es cuantitativa continua.
# La variiable alimentos es cuantitativa continua.
# La variiable ali_dentro es cuantitativa continua.
# La variiable cereales es cuantitativa continua.
# La variiable carnes es cuantitativa continua.
# La variiable pescado es cuantitativa continua.
# La variiable leche es cuantitativa continua.
# La variiable huevo es cuantitativa continua.
# La variiable aceites es cuantitativa continua.
# La variiable tuberculo es cuantitativa continua.
# La variiable verduras es cuantitativa continua.
# La variiable frutas es cuantitativa continua.
# La variiable azucar es cuantitativa continua.
# La variiable cafe es cuantitativa continua.
# La variiable especias es cuantitativa continua.
# La variiable otros_alim es cuantitativa continua.
# La variiable bebidas es cuantitativa continua.
# La variiable ali_fuera es cuantitativa continua.
# La variiable tabaco es cuantitativa continua.
# La variiable vesti_calz es cuantitativa continua.
# La variiable vestido es cuantitativa continua.
# La variiable calzado es cuantitativa continua.
# La variiable vivienda es cuantitativa continua.
# La variiable alquiler es cuantitativa continua.
# La variiable pred_cons es cuantitativa continua.
# La variiable agua es cuantitativa continua.
# La variiable energia es cuantitativa continua.
# La variiable limpieza es cuantitativa continua.
# La variiable cuidados es cuantitativa continua.
# La variiable utensilios es cuantitativa continua.
# La variiable enseres es cuantitativa continua.
# La variiable salud es cuantitativa continua.
# La variiable atenc_ambu es cuantitativa continua.
# La variiable hospital es cuantitativa continua.
# La variiable medicinas es cuantitativa continua.
# La variiable transporte es cuantitativa continua.
# La variiable publico es cuantitativa continua.
# La variiable foraneo es cuantitativa continua.
# La variiable adqui_vehi es cuantitativa continua.
# La variiable mantenim es cuantitativa continua.
# La variiable refaccion es cuantitativa continua.
# La variiable combus es cuantitativa continua.
# La variiable comunica es cuantitativa continua.
# La variiable educa_espa es cuantitativa continua.
# La variiable educacion es cuantitativa continua.
# La variiable esparci es cuantitativa continua.
# La variiable paq_turist es cuantitativa continua.
# La variiable personales es cuantitativa continua.
# La variiable cuida_pers es cuantitativa continua.
# La variiable acces_pers es cuantitativa continua.
# La variiable otros_gas es cuantitativa continua.
# La variiable transf_gas es cuantitativa continua.
# La variiable percep_tot es cuantitativa continua.
# La variiable retiro_inv es cuantitativa continua.
# La variiable prestamos es cuantitativa continua.
# La variiable otras_perc es cuantitativa continua.
# La variiable ero_nm_viv es cuantitativa continua.
# La variiable ero_nm_hog es cuantitativa continua.
# La variiable erogac_tot es cuantitativa continua.
# La variiable cuota_viv es cuantitativa continua.
# La variiable mater_serv es cuantitativa continua.
# La variiable material es cuantitativa continua.
# La variiable servicio es cuantitativa continua.
# La variiable deposito es cuantitativa continua.
# La variiable prest_terc es cuantitativa continua.
# La variiable pago_tarje es cuantitativa continua.
# La variiable deudas es cuantitativa continua.
# La variiable balance es cuantitativa continua.
# La variiable otras_erog es cuantitativa continua.
# La variiable smg es cuantitativa continua.

# %% [markdown]
# ---
#
#
# ## Gráficos de las frecuencias absolutas de las variables categoricas.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
var_cuali_l =['tam_loc',
 'est_socio',
 'clase_hog',
 'sexo_jefe',
 'educa_jefe']
var_cuali_l
# Out:
# ['tam_loc', 'est_socio', 'clase_hog', 'sexo_jefe', 'educa_jefe']

# %%
fig, ax = plt.subplots(2, 3, figsize=(20,10))
for variable, subplot in zip(var_cuali_l, ax.flatten()):
    sns.countplot(data[variable], ax=subplot)
    for label in subplot.get_xticklabels():
        label.set_rotation(90)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
var_cuali
# Out:
# Index(['folioviv', 'foliohog', 'ubica_geo', 'tam_loc', 'est_socio',
#        'clase_hog', 'sexo_jefe', 'edad_jefe', 'educa_jefe'],
#       dtype='object')

# %%
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{p:.2f}%  ({v:d})'.format(p=pct,v=val)
    return my_autopct

# %%
colors = ['#C70039','#FF5733','#FFC300','#DAF7A6']

# %%
plot = data['est_socio'].value_counts().plot(kind='pie', autopct=make_autopct(data['est_socio']), 
                                            figsize=(7, 7),colors=colors)
_ = plt.title('Clasificacion de viviendas')

# %%
plot = data['educa_jefe'].value_counts().plot(kind='pie', autopct=make_autopct(data['educa_jefe']), 
                                            figsize=(9, 9))
_ = plt.title('Educacion del jefe del hogar')

plt.show()

# %%
plot = data['sexo_jefe'].value_counts().plot(kind='pie', autopct=make_autopct(data['sexo_jefe']), 
                                            figsize=(7, 7),colors=['green','pink'])
_ = plt.title('Sexo del jefe del hogar')

plt.show()

# %%
# plot = data['tam_loc'].value_counts().plot(kind='pie', autopct=make_autopct(data['tam_loc']), 
                                            figsize=(7, 7),colors=colors)
# _ = plt.title('Clasificacion de viviendas')

# %% [markdown]
# ---
#
# ## Variables Cuantitativas.

# %% [markdown]
# ## **Variables Cuantitativas Discretas:**

# %%
sns.set()
data[var_cuanti_discret].hist(bins=15, figsize=(15, 6), layout=(2, 5));

# %% [markdown]
# ## **Variables Cuantitativas Continuas**

# %%
data[var_cuanti_conti]

# %%
grafica_1_cont = ['ing_cor'
,'ingtrab'
,'trabajo'
,'sueldos'
,'horas_extr'
,'comisiones'
,'aguinaldo'
,'indemtrab'
,'otra_rem'
,'remu_espec']

grafica_2_cont = ['negocio',
'noagrop'
,'industria'
,'comercio'
,'servicios'
,'agrope',
'agricolas'
,'pecuarios'
,'reproducc'
,'pesca'
]

grafica_3_cont = ['otros_trab'
,'rentas'
,'utilidad'
,'arrenda'
,'transfer'
,'jubilacion'
,'becas'
,'donativos'
,'remesas'
,'bene_gob']

grafica_4_cont = ['transf_gas',
'percep_tot',
'retiro_inv'
,'prestamos'
,'otras_perc'
,'ero_nm_viv'
,'ero_nm_hog'
,'erogac_tot'
,'cuota_viv'
,'mater_serv']

# %%
fig, ax = plt.subplots(2, 5, figsize=(20,10))
for variable, subplot in zip(grafica_1_cont, ax.flatten()):
    sns.kdeplot(data[variable], ax=subplot,color='orange')
    for label in subplot.get_xticklabels():
        label.set_rotation(90)

# %%
ig, ax = plt.subplots(2, 5, figsize=(20,10))
for variable, subplot in zip(grafica_2_cont, ax.flatten()):
    sns.kdeplot(data[variable], ax=subplot,color='red')
    for label in subplot.get_xticklabels():
        label.set_rotation(90)

# %%
ig, ax = plt.subplots(2, 5, figsize=(20,10))
for variable, subplot in zip(grafica_3_cont, ax.flatten()):
    sns.kdeplot(data[variable], ax=subplot,color='blue')
    for label in subplot.get_xticklabels():
        label.set_rotation(90)

# %%
ig, ax = plt.subplots(2, 5, figsize=(20,10))
for variable, subplot in zip(grafica_4_cont, ax.flatten()):
    sns.kdeplot(data[variable], ax=subplot,color='purple')
    for label in subplot.get_xticklabels():
        label.set_rotation(90)

# %% [markdown]
# ## RElaciones entre categoricos y numericos

# %%
fig, ax = plt.subplots(2, 3, figsize=(25, 15))
for var, subplot in zip(var_cuali_l, ax.flatten()):
    sns.boxplot(x=var, y='sueldos', data=data, ax=subplot)
